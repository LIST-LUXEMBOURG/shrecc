# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
from pathlib import Path

import numpy as np
import pandas as pd

# import brightway2 as bw
from bw2data.query import Filter, Query

# %%
import bw2data as bd

# %%
bd.projects
# Out:
# Brightway2 projects manager with 27 objects, including:
# 	BEST
# 	Delphi
# 	SHRECCbw25
# 	ai391
# 	autumn-school
# 	bw2 workshop
# 	bw25-tuto
# 	caritas
# 	default
# 	ecoinvent 3.8
# Use `sorted(projects)` to get full list, `projects.report()` to get
# 	a report on all projects.

# %%
import os
import sys

# %%
# Get the directory of the notebook
notebook_dir = os.getcwd()

# Assuming the SHRECC directory is the parent of the current directory
project_root = os.path.abspath(os.path.join(notebook_dir, os.pardir))

# Add the project root to the Python path
sys.path.append(project_root)

# %%
from shrecc.download import download_shrecc_data

# %%
download_shrecc_data(
    private_token="p9rJkg1tUh_v_c-CdDSK", destination_directory="/tmp/shrecc_tmp_data"
)
# Out:
# Cloning into '/tmp/tmpapyx8x4a'...
# Failed to clone repository. Error: Command '['git', 'clone', '--depth', '1', '--branch', 'main', 'https://oauth2:p9rJkg1tUh_v_c-CdDSK@git.list.lu/shrecc_project/shrecc_data/', '/tmp/tmpapyx8x4a']' returned non-zero exit status 128.
# Please make sure you have git installed.
# This can _also_ be done using conda
# remote: HTTP Basic: Access denied. The provided password or token is incorrect or your account has 2FA enabled and you must use a personal access token instead of a password. See https://git.list.lu/help/topics/git/troubleshooting_git#error-on-git-fetch-http-basic-access-denied
# fatal: Authentication failed for 'https://git.list.lu/shrecc_project/shrecc_data/'

# %%
from SHRECC.database import tech_mapping

# %%
countries = ["FR", "ES", "IT", "GR", "DK", "NL"]

# %%
from SHRECC.database import filt_cutoff

# %%
# Load the data from the default location
zkouska = filt_cutoff(
    countries=countries,
    general_range=["2023-03-01 01:00:00", "2023-08-31 23:00:00"],
    freq="D",
    cutoff=1e-3,
    include_cutoff=True,
)
# Out:
# Loading data from /home/navarrete_31625/.local/share/SHRECC
# Filtering by country before multiplying✅
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:65: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   Z_cons_to_multiply = Z_cons.drop("trade", axis=0).copy()
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df_filt = df_filt.groupby(level="country", axis=1).mean()
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:155: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_filt.loc[

# %%
# using a specific location
zkouska = filt_cutoff(
    countries=countries,
    general_range=["2023-03-01 01:00:00", "2023-09-30 23:00:00"],
    freq="D",
    cutoff=1e-3,
    include_cutoff=True,
    data_root="/tmp/shrecc_tmp_data",
)
# Out:
# Loading data from /tmp/shrecc_tmp_data
# Filtering by country before multiplying✅
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:65: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   Z_cons_to_multiply = Z_cons.drop("trade", axis=0).copy()
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:146: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df_filt = df_filt.groupby(level="country", axis=1).mean()
# /home/navarrete_31625/workspaces/sabina.bednarova/shrecc/SHRECC/database.py:155: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_filt.loc[

# %%
zkouska
# Out:
# country                                                                                                       DK  \
# geography_source activityName                                       product                   unitName
# AT               electricity production, deep geothermal            electricity, high voltage kWh       0.000000
#                  electricity production, hard coal                  electricity, high voltage kWh       0.000000
#                  electricity production, hydro, pumped storage      electricity, high voltage kWh       0.000000
#                  electricity production, hydro, reservoir, alpin... electricity, high voltage kWh       0.000000
#                  electricity production, hydro, run-of-river        electricity, high voltage kWh       0.000000
# ...                                                                                                          ...
# ...

# %%
bd.projects.set_current("ecoinvent391")

# %%
bd.databases

# %%
from SHRECC.database import create_database

# %%
create_database(zkouska, "ecoinvent391", "elec913", "ecoinvent391-cutoff")

# %%
bd.databases

# %%
elec913db = bd.Database("elec913")

# %%
print(f"There are {len(elec913db)} activities in {elec913db}")

# %%
for a in bd.Database("elec913"):
    print(a)
    print(f"\t {a['code']}")

# %%
import bw2calc as bc

# %%
ef_keys = [m for m in bd.methods if m[0] == "EF v3.1" and m[1] == "climate change"]
ef_keys

# %%
emix_gr = bd.Database("elec913").get("electricity 3")
emix_gr

# %%
a_lca = bc.LCA({emix_gr: 1}, ef_keys[0])

# %%
a_lca.lci()
a_lca.lcia()
a_lca.score
